# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('salary_class.csv')

# %%
df
# Out:
#        Unnamed: 0  age     workclass     education  education-num
# 0               0   25       Private          11th              7  \
# 1               1   38       Private       HS-grad              9
# 2               2   28     Local-gov    Assoc-acdm             12
# 3               3   44       Private  Some-college             10
# 4               4   18           NaN  Some-college             10
# ...           ...  ...           ...           ...            ...
# 48837       48837   27       Private    Assoc-acdm             12
# 48838       48838   40       Private       HS-grad              9
# 48839       48839   58       Private       HS-grad              9
# 48840       48840   22       Private       HS-grad              9
# 48841       48841   52  Self-emp-inc       HS-grad              9
#
#            marital-status         occupation relationship   race     sex
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      48842 non-null  int64
#  1   age             48842 non-null  int64
#  2   workclass       46043 non-null  object
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      46033 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  object
#  14  class           48842 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0           age  education-num  capital-gain  capital-loss
# count  48842.000000  48842.000000   48842.000000  48842.000000  48842.000000  \
# mean   24420.500000     38.643585      10.078089   1079.067626     87.502314
# std    14099.615261     13.710510       2.570973   7452.019058    403.004552
# min        0.000000     17.000000       1.000000      0.000000      0.000000
# 25%    12210.250000     28.000000       9.000000      0.000000      0.000000
# 50%    24420.500000     37.000000      10.000000      0.000000      0.000000
# 75%    36630.750000     48.000000      12.000000      0.000000      0.000000
# max    48841.000000     90.000000      16.000000  99999.000000   4356.000000
#
#        hours-per-week         class
# count    48842.000000  48842.000000
# mean        40.422382      0.239282
# std         12.391444      0.426649
# min          1.000000      0.000000
# 25%         40.000000      0.000000
# 50%         40.000000      0.000000
# ...

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0           age workclass education  education-num
# count   48842.000000  48842.000000     46043     48842   48842.000000  \
# unique           NaN           NaN         8        16            NaN
# top              NaN           NaN   Private   HS-grad            NaN
# freq             NaN           NaN     33906     15784            NaN
# mean    24420.500000     38.643585       NaN       NaN      10.078089
# std     14099.615261     13.710510       NaN       NaN       2.570973
# min         0.000000     17.000000       NaN       NaN       1.000000
# 25%     12210.250000     28.000000       NaN       NaN       9.000000
# 50%     24420.500000     37.000000       NaN       NaN      10.000000
# 75%     36630.750000     48.000000       NaN       NaN      12.000000
# max     48841.000000     90.000000       NaN       NaN      16.000000
#
#             marital-status      occupation relationship   race    sex
# ...

# %%
#인코딩해야하는 데이터만 확인해 보자

obj_list = []
for i in df.columns:
    if df[i].dtype=='object':
        obj_list.append(i)
        
df[obj_list]
# Out:
#           workclass     education      marital-status         occupation
# 0           Private          11th       Never-married  Machine-op-inspct  \
# 1           Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2         Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3           Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 4               NaN  Some-college       Never-married                NaN
# ...             ...           ...                 ...                ...
# 48837       Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 48838       Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 48839       Private       HS-grad             Widowed       Adm-clerical
# 48840       Private       HS-grad       Never-married       Adm-clerical
# 48841  Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
#       relationship   race     sex native-country
# ...

# %%
df_obj= df[obj_list]

# %%
# 교윳값들에 대한 판단
df_obj['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df_obj
# Out:
#           workclass     education      marital-status         occupation
# 0           Private          11th       Never-married  Machine-op-inspct  \
# 1           Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2         Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3           Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 4               NaN  Some-college       Never-married                NaN
# ...             ...           ...                 ...                ...
# 48837       Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 48838       Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 48839       Private       HS-grad             Widowed       Adm-clerical
# 48840       Private       HS-grad       Never-married       Adm-clerical
# 48841  Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
#       relationship   race     sex native-country
# ...

# %%
df
# Out:
#        Unnamed: 0  age     workclass     education  education-num
# 0               0   25       Private          11th              7  \
# 1               1   38       Private       HS-grad              9
# 2               2   28     Local-gov    Assoc-acdm             12
# 3               3   44       Private  Some-college             10
# 4               4   18           NaN  Some-college             10
# ...           ...  ...           ...           ...            ...
# 48837       48837   27       Private    Assoc-acdm             12
# 48838       48838   40       Private       HS-grad              9
# 48839       48839   58       Private       HS-grad              9
# 48840       48840   22       Private       HS-grad              9
# 48841       48841   52  Self-emp-inc       HS-grad              9
#
#            marital-status         occupation relationship   race     sex
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male  \
# ...

# %%
df_obj['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
df_obj['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df_obj['race'].value_counts()
# Out:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
df_obj['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# ...

# %% [markdown]
# - 데이터에 대한 근본적인 이해가 필요하다.
# - 분석하기전에 데이터관의 관계와 로직을 꼭 이해야 한다.
#
# - age, education, sex, hours-per-week, native-country, class

# %%
df_base= df[['age','education-num','sex','hours-per-week','native-country','race','class']]

# %%
df_base
# Out:
#        age  education-num     sex  hours-per-week native-country   race  class
# 0       25              7    Male              40  United-States  Black      0
# 1       38              9    Male              50  United-States  White      0
# 2       28             12    Male              40  United-States  White      1
# 3       44             10    Male              40  United-States  Black      1
# 4       18             10  Female              30  United-States  White      0
# ...    ...            ...     ...             ...            ...    ...    ...
# 48837   27             12  Female              38  United-States  White      0
# 48838   40              9    Male              40  United-States  White      1
# 48839   58              9  Female              40  United-States  White      0
# 48840   22              9    Male              20  United-States  White      0
# 48841   52              9  Female              40  United-States  White      1
#
# ...

# %%
df_base['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# ...

# %% [markdown]
# - 1. 데이터의 분포가 대부분 미국이니깐 미국과 미국이 아닌 것
# - 2. 대륙별로도 묶을 수 있다.
# - 3. EU 화폐가치에 대해서 같이 묶을 수 있는 묶거나

# %% [markdown]
# - y값과 관계를 꼭 살펴봐야 한다.
#
# - 독일은 연봉이 높은 경우가 대부분이다 1이 많다
# - 폴란드는 연봉이 낮은 경우가 대부분이다. 0이 많다.
# - 클래스가 불균형한 것들이 같이 묶여지면- > 편향이 생긴다?
# - 그냥 대륙별로 묶게 되면 위의 경우가 발생할 때는 모델링 성능 영향을 미칠 수 있다.
#
# - class에 대한 것이 근거로 확인해야 한다.

# %%
## 이진 분류의 경우
df_base.groupby('native-country')['class'].mean()
# 1이 연봉이 높은 것
# 0이 연봉이 낮은 것
# 평균이 높다는 것은 -> 연봉이 높다는 것
# class의 평균이 높은 국가들은 1에 대한 비중이 높다.
# Out:
# native-country
# Cambodia                      0.321429
# Canada                        0.346154
# China                         0.295082
# Columbia                      0.047059
# Cuba                          0.246377
# Dominican-Republic            0.048544
# Ecuador                       0.133333
# El-Salvador                   0.070968
# England                       0.370079
# France                        0.421053
# Germany                       0.281553
# Greece                        0.367347
# Guatemala                     0.034091
# Haiti                         0.120000
# Holand-Netherlands            0.000000
# Honduras                      0.100000
# Hong                          0.266667
# Hungary                       0.315789
# India                         0.410596
# Iran                          0.372881
# Ireland                       0.297297
# Italy                         0.323810
# Jamaica                       0.141509
# ...

# %% [markdown]
# - class가 높은 국가끼리 묶여주면
# - 2가지
# - 1 class가 높은 애들은 어떤 특성이 있나? 2차 분석이 필요하다. -> 아 다른 변수들도 뭔가 건들 수 있겠다.
# - 2. unique 값도 생각을 해서 진행해야 한다.
#
# - 피처엔지니어링 개념으로 접근시에는 이 새로운 파생변수로 사용할 수도 있다.
#
#
# ## class 우리가 예측해야 할 정답에 대해서 근거  기준을 가지고 꼭 데이터를 전처리 해야 한다!

# %%
df
# Out:
#        Unnamed: 0  age     workclass     education  education-num
# 0               0   25       Private          11th              7  \
# 1               1   38       Private       HS-grad              9
# 2               2   28     Local-gov    Assoc-acdm             12
# 3               3   44       Private  Some-college             10
# 4               4   18           NaN  Some-college             10
# ...           ...  ...           ...           ...            ...
# 48837       48837   27       Private    Assoc-acdm             12
# 48838       48838   40       Private       HS-grad              9
# 48839       48839   58       Private       HS-grad              9
# 48840       48840   22       Private       HS-grad              9
# 48841       48841   52  Self-emp-inc       HS-grad              9
#
#            marital-status         occupation relationship   race     sex
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male  \
# ...

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   education-num   48842 non-null  int64
#  2   sex             48842 non-null  object
#  3   hours-per-week  48842 non-null  int64
#  4   native-country  47985 non-null  object
#  5   class           48842 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 2.2+ MB

# %%
df_base.dropna(inplace=True)
# Out:
# /var/folders/sz/167qwb595mqgwry5mm8685n00000gn/T/ipykernel_89712/4041985548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_base.dropna(inplace=True)

# %%
#기본 베이스 라인 모델을 모델링 해보자!

df_base=pd.get_dummies(df_base)

# %%
df_base= df_base*1

# %%
df_base.columns
# Out:
# Index(['age', 'education-num', 'hours-per-week', 'class', 'sex_Female',
#        'sex_Male', 'native-country_Cambodia', 'native-country_Canada',
#        'native-country_China', 'native-country_Columbia',
#        'native-country_Cuba', 'native-country_Dominican-Republic',
#        'native-country_Ecuador', 'native-country_El-Salvador',
#        'native-country_England', 'native-country_France',
#        'native-country_Germany', 'native-country_Greece',
#        'native-country_Guatemala', 'native-country_Haiti',
#        'native-country_Holand-Netherlands', 'native-country_Honduras',
#        'native-country_Hong', 'native-country_Hungary', 'native-country_India',
#        'native-country_Iran', 'native-country_Ireland', 'native-country_Italy',
#        'native-country_Jamaica', 'native-country_Japan', 'native-country_Laos',
#        'native-country_Mexico', 'native-country_Nicaragua',
#        'native-country_Outlying-US(Guam-USVI-etc)', 'native-country_Peru',
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_base.drop('class',axis=1),df_base['class'], test_size=0.4, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.776023757424195

# %% [markdown]
# ### 파생변수를 만들어서 피처엔지니어링으로 변수를 최소화 하고 진행해 보자!

# %%
df_base2= df[['age','education-num','sex','hours-per-week','native-country','race','class']]

# %%
df_base2.dropna(inplace=True)
# Out:
# /var/folders/sz/167qwb595mqgwry5mm8685n00000gn/T/ipykernel_89712/2595896158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_base2.dropna(inplace=True)

# %%
df_base2
# Out:
#        age  education-num     sex  hours-per-week native-country   race  class
# 0       25              7    Male              40  United-States  Black      0
# 1       38              9    Male              50  United-States  White      0
# 2       28             12    Male              40  United-States  White      1
# 3       44             10    Male              40  United-States  Black      1
# 4       18             10  Female              30  United-States  White      0
# ...    ...            ...     ...             ...            ...    ...    ...
# 48837   27             12  Female              38  United-States  White      0
# 48838   40              9    Male              40  United-States  White      1
# 48839   58              9  Female              40  United-States  White      0
# 48840   22              9    Male              20  United-States  White      0
# 48841   52              9  Female              40  United-States  White      1
#
# ...

# %%
df_fn=df_base2.groupby('native-country')['class'].mean()

# %%
df_fn=df_fn.reset_index()

# %%
df_base2_final=df_base2.merge(df_fn, on='native-country',how='left')

# %%
df_base2f =df_base2_final[['age','education-num','sex','hours-per-week','class_x','class_y','race']]

# %%
df_base2f=df_base2f.rename(columns = {'class_x':'class', 'class_y':'native-country'})

# %%
df_base2f
# Out:
#        age  education-num     sex  hours-per-week  class  native-country
# 0       25              7    Male              40      0        0.243977  \
# 1       38              9    Male              50      0        0.243977
# 2       28             12    Male              40      1        0.243977
# 3       44             10    Male              40      1        0.243977
# 4       18             10  Female              30      0        0.243977
# ...    ...            ...     ...             ...    ...             ...
# 47980   27             12  Female              38      0        0.243977
# 47981   40              9    Male              40      1        0.243977
# 47982   58              9  Female              40      0        0.243977
# 47983   22              9    Male              20      0        0.243977
# 47984   52              9  Female              40      1        0.243977
#
#         race
# 0      Black
# 1      White
# 2      White
# 3      Black
# 4      White
# ...

# %%
df_base2f=pd.get_dummies(df_base2f)

# %%
df_base2f=df_base2f*1

# %%
df_base2f
# Out:
#        age  education-num  hours-per-week  class  native-country  sex_Female
# 0       25              7              40      0        0.243977           0  \
# 1       38              9              50      0        0.243977           0
# 2       28             12              40      1        0.243977           0
# 3       44             10              40      1        0.243977           0
# 4       18             10              30      0        0.243977           1
# ...    ...            ...             ...    ...             ...         ...
# 47980   27             12              38      0        0.243977           1
# 47981   40              9              40      1        0.243977           0
# 47982   58              9              40      0        0.243977           1
# 47983   22              9              20      0        0.243977           0
# 47984   52              9              40      1        0.243977           1
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_base2f.drop('class',axis=1),df_base2f['class'], test_size=0.4, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.7752422632072523

# %% [markdown]
# 0.7820152130874232

# %% [markdown]
# - 인코딩을 그냥 바로 진행한 경우 0.7820152130874232
# - 엔지니어링을 한 경우 0.781702615400646

# %%
0.7820152130874232 - 0.781702615400646
# Out:
# 0.0003125976867771607

# %% [markdown]
# - 만약 정확도를 더 높이려면 어떻게 해야하나?

# %% [markdown]
# - 더 많은 데이터를 넣어서 학습시킨다.
# - 하이퍼파라미터를 튜닝한다.
# - 다른 모델을 쓸 수 있다.

# %% [markdown]
# ###  새로운 데이터를 추가해 정확도를 높여보자!
# - race 인종에 대한 데이터를 추가해 보자!
# - 기본 베이스 라인 모델 정확도 : 0.776023757424195
# - 피처엔지니어링에 + race 변수 추가 : 0.7752422632072523

# %%
0.776023757424195- 0.7752422632072523
# Out:
# 0.0007814942169427352

# %% [markdown]
# - 변수를 단순하게 추가하여 인코딩하는 것이 정확도를 높이는 것에 대해서는 오히려 반대의 결과를 줄 수 있다.
# - 데이터가 race가 없는 경우가 더 높은 정확도를 보였다.
# - 단순하게 바라보는 게 아니라 Class 에 대한 영향도, 실제 데이터를 추가 햇을 때 모델의 성능, 컬럼과의 관계 등을 살펴보고
# - 이런 것들으 다 종합적으로 판단한 후에 성능을 높여야 한다.

# %% [markdown]
# - 전처리에 대한 역량이 꼭 필요하다.

# %% [markdown]
# ### 필수과제 ( 하지 않으면 우수학회원이 될 수 없다.)
# - 다른 변수를 사용해서 전처리를 진행하고
# - 실제 전처리하여 기존의 0.782보다 더 높은 성능을 만들어 주셔야 합니다.
# - 분석 리포팅을 해야 하는 과정에서 잘 하고 있는지 못하는지에 대한 평가 기준
# - 다음 시간에는 본인들의 스코어와 전처리 하신 방법을 질문하려고 합니다.
